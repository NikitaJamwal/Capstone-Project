# %% [markdown]
# # 1. Introduction

# %% [markdown]
# We all know that Health care is very important domain in the market. It is directly linked with the life of the individual; hence we have to be always be proactive in this particular domain. Money plays a major role in this domain, because sometime treatment becomes super costly and if any individual is not covered under the insurance then it will become a pretty tough financial situation for that individual. The companies in the medical insurance also want to reduce their risk by optimizing the insurance cost, because we all know a healthy body is in the hand of the individual only. If individual eat healthy and do proper exercise the chance of getting ill is drastically reduced.

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# The objective of this exercise is to build a model, using data that provide the optimum insurance cost for an individual by using the health and habit related parameters for the estimated cost of insurance

# %% [markdown]
# ### Need of the study/project

# %% [markdown]
# 1.Analyze relevant data: To build a predictive model, we need to analyze the data. In this case, we need to analyze data on health and habit-related parameters and their relationship with insurance costs.
# 2.Define the target variable: In this case, the target variable is the insurance cost.
# 3.Select appropriate modeling techniques: We need to select appropriate modeling techniques that will help us build an accurate predictive model.
# We may need to consider techniques such as linear regression, decision trees, or neural networks.
# 4.Feature engineering: We need to identify the most relevant features or variables that affect insurance costs.
# We may need to do feature engineering to create new features or transform existing features to make them more relevant for our model.
# 5.Model evaluation: Once we have built our model, we need to evaluate its performance using appropriate metrics.
# We need to ensure that our model is accurate and generalizes well to new data. 6.Interpretation: Finally, we need to interpret the results of our model.
# We need to identify the key factors that affect insurance costs and provide insights that can help insurance companies make better decisions.

# %% [markdown]
# ### Understanding business social/social opportunity

# %% [markdown]
# 1.Improved risk assessment: By using a predictive model, insurance companies can better assess the risk associated with insuring an individual. This can help them determine appropriate premiums and reduce the likelihood of losses.
# 2.More personalized insurance plans: A predictive model can help insurance companies create more personalized insurance plans that are tailored to an individual's health and lifestyle.
# This can lead to higher customer satisfaction and retention.
# 3.Improved health outcomes: By providing incentives for healthier lifestyles, insurance companies can encourage individuals to adopt healthier habits.
# This can lead to improved health outcomes and reduced healthcare costs.
# 4.Competitive advantage: By leveraging data and analytics to make better decisions, insurance companies can gain a competitive advantage in the marketplace.
# They can differentiate themselves by offering more personalized and affordable insurance plans.
# 5.Social impact: By providing more affordable and accessible insurance plans, insurance companies can contribute to broader social goals of improving healthcare access and reducing healthcare disparities.

# %% [markdown]
# # 2. EDA and Business Implication

# %% [markdown]
# ### Non- Visual inspection of data (rows, columns, descriptive details)

# %%
#Loading the libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Loading the dataset

df_1 = pd.read_csv(r"C:\Users\cliff\OneDrive\Desktop\Great Learning\Capstone Project\Data.csv")

# %%
#Viewing the first five records of the data

df_1.head()
# Out:
#    applicant_id  years_of_insurance_with_us  regular_checkup_lasy_year  \
# 0          5000                           3                          1
# 1          5001                           0                          0
# 2          5002                           1                          0
# 3          5003                           7                          4
# 4          5004                           3                          1
#
#    adventure_sports Occupation  visited_doctor_last_1_year cholesterol_level  \
# 0                 1    Salried                           2        125 to 150
# 1                 0    Student                           4        150 to 175
# 2                 0   Business                           4        200 to 225
# 3                 0   Business                           2        175 to 200
# 4                 0    Student                           2        150 to 175
#
#    daily_avg_steps  age  heart_decs_history  ...   smoking_status  \
# ...

# %%
#Viewing the last first five records of the data

df_1.tail()
# Out:
#        applicant_id  years_of_insurance_with_us  regular_checkup_lasy_year  \
# 24995         29995                           3                          0
# 24996         29996                           6                          0
# 24997         29997                           7                          0
# 24998         29998                           1                          0
# 24999         29999                           8                          2
#
#        adventure_sports Occupation  visited_doctor_last_1_year  \
# 24995                 0    Salried                           4
# 24996                 0   Business                           4
# 24997                 1    Student                           2
# 24998                 0    Salried                           2
# 24999                 0   Business                           4
#
#       cholesterol_level  daily_avg_steps  age  heart_decs_history  ...  \
# ...

# %%
#Checking summary of the data

df_1.describe()
# Out:
#        applicant_id  years_of_insurance_with_us  regular_checkup_lasy_year  \
# count  25000.000000                25000.000000               25000.000000
# mean   17499.500000                    4.089040                   0.773680
# std     7217.022701                    2.606612                   1.199449
# min     5000.000000                    0.000000                   0.000000
# 25%    11249.750000                    2.000000                   0.000000
# 50%    17499.500000                    4.000000                   0.000000
# 75%    23749.250000                    6.000000                   1.000000
# max    29999.000000                    8.000000                   5.000000
#
#        adventure_sports  visited_doctor_last_1_year  daily_avg_steps  \
# count      25000.000000                25000.000000     25000.000000
# mean           0.081720                    3.104200      5215.889320
# std            0.273943                    1.141663      1053.179748
# ...

# %% [markdown]
# From the summary of the data we can understand few points like,
#
# Years_of_insuarance_with_us column has mean of 4.08 which is 4 years , means the mean duration a customer has been with the company is 4 years, of which 8 years is the maximum record for the association while 0 years which means there are some people who have been associated for less than a year.
#
# Average age of customer that comes for insurance is 44, while 74 is the maximum and miinimum is 16.
#
# Mean BMI for an individual is 31, maximum is 100 which sounds suspicious, data has to be checked.
#
# The average weight is 71, maximum is 96 and minimum is 52.
#
# Average Fat percentage in an individual is 28%, Maximum is 42% and minimum is 11%.
#
# Average insurance cost is 27,147 INR which can go upto the maximum amount of 67,870 INR and minimum of 2,468 INR.

# %%
#Checking the shape of the data

df_1.shape
# Out:
# (25000, 24)

# %%
# Checking the info of the data

df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   applicant_id                    25000 non-null  int64
#  1   years_of_insurance_with_us      25000 non-null  int64
#  2   regular_checkup_lasy_year       25000 non-null  int64
#  3   adventure_sports                25000 non-null  int64
#  4   Occupation                      25000 non-null  object
#  5   visited_doctor_last_1_year      25000 non-null  int64
#  6   cholesterol_level               25000 non-null  object
#  7   daily_avg_steps                 25000 non-null  int64
#  8   age                             25000 non-null  int64
#  9   heart_decs_history              25000 non-null  int64
#  10  other_major_decs_history        25000 non-null  int64
#  11  Gender                          25000 non-null  object
# ...

# %% [markdown]
# From the info() command we can see that:
#
# We have 2 columns with float datatype,14 columns with integer datatype and 8 columns with object datatype. Columns such as 'Bmi', 'Year_last_admitted' have some null values.

# %%
#Checking the Null values

df_1.isnull().sum()
# Out:
# applicant_id                          0
# years_of_insurance_with_us            0
# regular_checkup_lasy_year             0
# adventure_sports                      0
# Occupation                            0
# visited_doctor_last_1_year            0
# cholesterol_level                     0
# daily_avg_steps                       0
# age                                   0
# heart_decs_history                    0
# other_major_decs_history              0
# Gender                                0
# avg_glucose_level                     0
# bmi                                 990
# smoking_status                        0
# Year_last_admitted                11881
# Location                              0
# weight                                0
# covered_by_any_other_company          0
# Alcohol                               0
# exercise                              0
# weight_change_in_last_one_year        0
# fat_percentage                        0
# ...

# %% [markdown]
# We have 990 in BMI column and 11881 missing values in Year_last_submitted column in the dataset. 39% of data in bmi column is missing and 48% of data from year_last_admitted column is missing

# %%
#Checking duplicate values

df_1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Visual understanding of the data

# %%
#Removing the 'applicant_id' column which is not needed for analysis
df_new = df_1.drop(['applicant_id', 'Location'], axis=1)

# %%
df_new.head()
# Out:
#    years_of_insurance_with_us  regular_checkup_lasy_year  adventure_sports  \
# 0                           3                          1                 1
# 1                           0                          0                 0
# 2                           1                          0                 0
# 3                           7                          4                 0
# 4                           3                          1                 0
#
#   Occupation  visited_doctor_last_1_year cholesterol_level  daily_avg_steps  \
# 0    Salried                           2        125 to 150             4866
# 1    Student                           4        150 to 175             6411
# 2   Business                           4        200 to 225             4509
# 3   Business                           2        175 to 200             6214
# 4    Student                           2        150 to 175             4938
#
# ...

# %% [markdown]
# # 3. Data Cleaning and Pre-processing

# %% [markdown]
# ### Variable transformation

# %%
df_new['Occupation'].unique()
# Out:
# array(['Salried', 'Student', 'Business'], dtype=object)

# %%
df_new["Occupation"] = df_new["Occupation"].replace({'Salried':2, 'Student':1, 'Business':3})

#Student=1
#Salaried=2
#Business=3

# %%
df_new['cholesterol_level'].unique()
# Out:
# array(['125 to 150', '150 to 175', '200 to 225', '175 to 200',
#        '225 to 250'], dtype=object)

# %%
df_new["cholesterol_level"] = df_new["cholesterol_level"].replace({'125 to 150':0, '150 to 175':1, '175 to 200':2, '200 to 225' :3,
                                                                  '225 to 250':4})

#125 to 150=0
#150 to 175=1
#175 to 200=2
#200 to 225 =3
#225 to 250= 4

# %%
df_new['smoking_status'].unique()
# Out:
# array(['Unknown', 'formerly smoked', 'never smoked', 'smokes'],
#       dtype=object)

# %%
df_new["smoking_status"] = df_new["smoking_status"].replace({'never smoked':0, 'smokes':1, 'formerly smoked':2, 'Unknown':3})

#never smoked=0
#smokes=1
#formerly smoked =2
#Unknown= 3

# %%
df_new['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df_new["Gender"] = df_new["Gender"].replace({'Male':0, 'Female':1})

#Male=0
#Female=1

# %%
df_new['covered_by_any_other_company'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df_new["covered_by_any_other_company"] = df_new["covered_by_any_other_company"].replace({'N':0, 'Y':1})

#N=0
#Y=1

# %%
df_new['Alcohol'].unique()
# Out:
# array(['Rare', 'Daily', 'No'], dtype=object)

# %%
df_new["Alcohol"] = df_new["Alcohol"].replace({'No':0, 'Daily':1, 'Rare': 2})

#No=0
#Daily=1
#Rare= 2

# %%
df_new['exercise'].unique()
# Out:
# array(['Moderate', 'Extreme', 'No'], dtype=object)

# %%
df_new["exercise"] = df_new["exercise"].replace({'No':0, 'Extreme':1, 'Moderate': 2})

#No=0
#Extreme=1
#Moderate= 2

# %%
df_new.head()
# Out:
#    years_of_insurance_with_us  regular_checkup_lasy_year  adventure_sports  \
# 0                           3                          1                 1
# 1                           0                          0                 0
# 2                           1                          0                 0
# 3                           7                          4                 0
# 4                           3                          1                 0
#
#    Occupation  visited_doctor_last_1_year  cholesterol_level  daily_avg_steps  \
# 0           2                           2                  0             4866
# 1           1                           4                  1             6411
# 2           3                           4                  3             4509
# 3           3                           2                  2             6214
# 4           1                           2                  1             4938
#
# ...

# %% [markdown]
# ### Missing Value treatment

# %%
df_new.isnull().sum()
# Out:
# years_of_insurance_with_us            0
# regular_checkup_lasy_year             0
# adventure_sports                      0
# Occupation                            0
# visited_doctor_last_1_year            0
# cholesterol_level                     0
# daily_avg_steps                       0
# age                                   0
# heart_decs_history                    0
# other_major_decs_history              0
# Gender                                0
# avg_glucose_level                     0
# bmi                                 990
# smoking_status                        0
# Year_last_admitted                11881
# weight                                0
# covered_by_any_other_company          0
# Alcohol                               0
# exercise                              0
# weight_change_in_last_one_year        0
# fat_percentage                        0
# insurance_cost                        0
# dtype: int64

# %%
df_new.median()
# Out:
# years_of_insurance_with_us            4.0
# regular_checkup_lasy_year             0.0
# adventure_sports                      0.0
# Occupation                            2.0
# visited_doctor_last_1_year            3.0
# cholesterol_level                     1.0
# daily_avg_steps                    5089.0
# age                                  45.0
# heart_decs_history                    0.0
# other_major_decs_history              0.0
# Gender                                0.0
# avg_glucose_level                   168.0
# bmi                                  30.5
# smoking_status                        1.0
# Year_last_admitted                 2004.0
# weight                               72.0
# covered_by_any_other_company          0.0
# Alcohol                               2.0
# exercise                              2.0
# weight_change_in_last_one_year        3.0
# fat_percentage                       31.0
# insurance_cost                    27148.0
# dtype: float64

# %%
#Treating missing values using Median

medianFiller = lambda x: x.fillna(x.median())
cols_to_fill = ['bmi', 'Year_last_admitted']
df_new[cols_to_fill] = df_new[cols_to_fill].apply(medianFiller, axis=0)

# %%
df_new.isnull().sum()
# Out:
# years_of_insurance_with_us        0
# regular_checkup_lasy_year         0
# adventure_sports                  0
# Occupation                        0
# visited_doctor_last_1_year        0
# cholesterol_level                 0
# daily_avg_steps                   0
# age                               0
# heart_decs_history                0
# other_major_decs_history          0
# Gender                            0
# avg_glucose_level                 0
# bmi                               0
# smoking_status                    0
# Year_last_admitted                0
# weight                            0
# covered_by_any_other_company      0
# Alcohol                           0
# exercise                          0
# weight_change_in_last_one_year    0
# fat_percentage                    0
# insurance_cost                    0
# dtype: int64

# %% [markdown]
# ### Univariate analysis

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   years_of_insurance_with_us      25000 non-null  int64
#  1   regular_checkup_lasy_year       25000 non-null  int64
#  2   adventure_sports                25000 non-null  int64
#  3   Occupation                      25000 non-null  int64
#  4   visited_doctor_last_1_year      25000 non-null  int64
#  5   cholesterol_level               25000 non-null  int64
#  6   daily_avg_steps                 25000 non-null  int64
#  7   age                             25000 non-null  int64
#  8   heart_decs_history              25000 non-null  int64
#  9   other_major_decs_history        25000 non-null  int64
#  10  Gender                          25000 non-null  int64
#  11  avg_glucose_level               25000 non-null  int64
# ...

# %%
df_new.boxplot(column=['daily_avg_steps', 'age','avg_glucose_level','bmi','Year_last_admitted','weight'], rot=90, figsize=(25,10))
plt.show()

# %%
df_new.boxplot(column=['fat_percentage', 'insurance_cost','years_of_insurance_with_us','regular_checkup_lasy_year',
                       'visited_doctor_last_1_year','weight_change_in_last_one_year'], rot=90, figsize=(25,10))
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
#For doing the correlation on continuous data we hav dropped all the categorical columns in another dataset.

df_eda= df_new.drop(["adventure_sports","Occupation","cholesterol_level","heart_decs_history","other_major_decs_history",
                    "Gender","smoking_status","covered_by_any_other_company","Alcohol","exercise"], axis=1)

# %%
df_eda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   years_of_insurance_with_us      25000 non-null  int64
#  1   regular_checkup_lasy_year       25000 non-null  int64
#  2   visited_doctor_last_1_year      25000 non-null  int64
#  3   daily_avg_steps                 25000 non-null  int64
#  4   age                             25000 non-null  int64
#  5   avg_glucose_level               25000 non-null  int64
#  6   bmi                             25000 non-null  float64
#  7   Year_last_admitted              25000 non-null  float64
#  8   weight                          25000 non-null  int64
#  9   weight_change_in_last_one_year  25000 non-null  int64
#  10  fat_percentage                  25000 non-null  int64
#  11  insurance_cost                  25000 non-null  int64
# ...

# %%
#Viewing correlation only for numerical data and not categorical data 
plt.figure(figsize=(10,10))
sns.heatmap(df_eda.corr(), annot=True, fmt='.3f', cmap='coolwarm')
plt.show()

# %% [markdown]
# # 4. Model building

# %% [markdown]
# ### Building models without any scaling or VIF

# %% [markdown]
# ### Capture the target column into separate vectors for training set and test set

# %%
X = df_new.drop(["insurance_cost"], axis=1)

y = df_new.pop("insurance_cost")

# %%
y.head()
# Out:
# 0    20978
# 1     6170
# 2    28382
# 3    27148
# 4    29616
# Name: insurance_cost, dtype: int64

# %%
X.head()
# Out:
#    years_of_insurance_with_us  regular_checkup_lasy_year  adventure_sports  \
# 0                           3                          1                 1
# 1                           0                          0                 0
# 2                           1                          0                 0
# 3                           7                          4                 0
# 4                           3                          1                 0
#
#    Occupation  visited_doctor_last_1_year  cholesterol_level  daily_avg_steps  \
# 0           2                           2                  0             4866
# 1           1                           4                  1             6411
# 2           3                           4                  3             4509
# 3           3                           2                  2             6214
# 4           1                           2                  1             4938
#
# ...

# %% [markdown]
# ### Splitting data into training and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=1
)

# %%
# let's add the intercept to data
import statsmodels.api as sm
X = sm.add_constant(X)

# %% [markdown]
# ## Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Initialize a Random Forest Regressor model with hyperparameters
rf = RandomForestRegressor(n_estimators=100, max_depth=10, random_state=42)

# Train the model on the training set
rf.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = rf.predict(X_test)

# Evaluate the model performance using Root Mean Squared Error (RMSE)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error (RMSE) on testing set: {rmse}")
# Out:
# Root Mean Squared Error (RMSE) on testing set: 3031.8428607910187

# %%
# Make predictions on the train set
y_pred = rf.predict(X_train)

# Evaluate the model performance using Root Mean Squared Error (RMSE)
mse = mean_squared_error(y_train, y_pred)
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error (RMSE) on training set: {rmse}")
# Out:
# Root Mean Squared Error (RMSE) on training set: 2456.726577005944

# %% [markdown]
# ### Validating the Random Forest model on training and test sets

# %%
from sklearn.metrics import r2_score

# Evaluate the model performance using the score function of the model
score = rf.score(X_test, y_test)
print(f"Score of the model on testing set: {score:.2f}")
# Out:
# Score of the model on testing set: 0.95

# %%
# Evaluate the model performance using the score function of the model
score = rf.score(X_train, y_train)
print(f"Score of the model on training set: {score:.2f}")
# Out:
# Score of the model on training set: 0.97

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import numpy as np

# assume X and y are your data and target variables respectively

# split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# train random forest model
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

# predict on test set
y_pred = rf.predict(X_test)

# calculate MAPE
mape = mean_absolute_percentage_error(y_test, y_pred)

# calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

# calculate R2 score
r2 = r2_score(y_test, y_pred)

# print results
print("MAPE:", mape)
print("RMSE:", rmse)
print("R2 score:", r2)
# Out:
# MAPE: 0.11583371350211166
# RMSE: 3033.1995548572095
# R2 score: 0.954940990689788

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, r2_score
import numpy as np

# assume X_train and y_train are your training data and target variables respectively

# train random forest model
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

# predict on training set
y_pred_train = rf.predict(X_train)

# calculate MAPE on training set
mape_train = mean_absolute_percentage_error(y_train, y_pred_train)

# calculate RMSE on training set
rmse_train = np.sqrt(mean_squared_error(y_train, y_pred_train))

# calculate R2 score on training set
r2_train = r2_score(y_train, y_pred_train)

# print results
print("MAPE (training set):", mape_train)
print("RMSE (training set):", rmse_train)
print("R2 score (training set):", r2_train)
# Out:
# MAPE (training set): 0.043642022987002434
# RMSE (training set): 1151.3816521799636
# R2 score (training set): 0.9935514062653447

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ### Fitting the linear model

# %%
# let's add the intercept to data
import statsmodels.api as sm
X = sm.add_constant(X)

# %%
# For randomized data splitting
from sklearn.model_selection import train_test_split

# To build linear regression_model
import statsmodels.api as sm

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=1
)

# %%
olsmod = sm.OLS(y_train, X_train)
olsres = olsmod.fit()

# %%
# let's print the regression summary
print(olsres.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         insurance_cost   R-squared:                       0.945
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                 1.423e+04
# Date:                Fri, 05 May 2023   Prob (F-statistic):               0.00
# Time:                        20:28:07   Log-Likelihood:            -1.6702e+05
# No. Observations:               17500   AIC:                         3.341e+05
# Df Residuals:                   17478   BIC:                         3.343e+05
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
olsmod_test = sm.OLS(y_test, X_test)
olsres_test = olsmod_test.fit()

# %%
# let's print the regression summary
print(olsres_test.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         insurance_cost   R-squared:                       0.945
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     6156.
# Date:                Fri, 05 May 2023   Prob (F-statistic):               0.00
# Time:                        20:28:07   Log-Likelihood:                -71460.
# No. Observations:                7500   AIC:                         1.430e+05
# Df Residuals:                    7478   BIC:                         1.431e+05
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
from sklearn.linear_model import LinearRegression
# train linear regression model
reg = LinearRegression().fit(X_train, y_train)

# make predictions on train and test data
y_train_pred = reg.predict(X_train)
y_test_pred = reg.predict(X_test)

# calculate RMSE and MAPE for train data
rmse_train = mean_squared_error(y_train, y_train_pred, squared=False)
mape_train = mean_absolute_percentage_error(y_train, y_train_pred)

# calculate RMSE and MAPE for test data
rmse_test = mean_squared_error(y_test, y_test_pred, squared=False)
mape_test = mean_absolute_percentage_error(y_test, y_test_pred)

# print results
print("Train RMSE:", rmse_train)
print("Train MAPE:", mape_train)
print("Test RMSE:", rmse_test)
print("Test MAPE:", mape_test)
# Out:
# Train RMSE: 3377.9002145349114
# Train MAPE: 0.15250754383194068
# Test RMSE: 3331.940750461435
# Test MAPE: 0.15006362618858915

# %%
score = reg.score(X_train, y_train)
print(f"Score of the model on training set: {score:.2f}")
# Out:
# Score of the model on training set: 0.94

# %%
score = reg.score(X_test, y_test)
print(f"Score of the model on training set: {score:.2f}")
# Out:
# Score of the model on training set: 0.95

# %% [markdown]
# ### Interpretation of R^2

# %% [markdown]
# The R-squared value tells us that our model can explain 94.5% of the variance in the training set.

# %% [markdown]
# ### Interpretation of co-efficients

# %% [markdown]
# The coefficients tell us how one unit change in X can affect y. The sign of the coefficient indicates if the relationship is positive or negative. For example, in the dataset, an increase in 1 kg of weight will result in increase in the insurance cost

# %% [markdown]
# ### Interpretation of p-values (P > |t|)

# %% [markdown]
# For each predictor variable there is a null hypothesis and alternate hypothesis.
#
# Null hypothesis : Predictor variable is not significant
# Alternate hypothesis : Predictor variable is significant (P > |t|) gives the p-value for each predictor variable to check the null hypothesis.
# If the level of significance is set to 5% (0.05), the p-values greater than 0.05 would indicate hat the corresponding predictor variables are not significant. However, due to the presence of multicollinearity in our data, the p-values will also change.
#
# We need to ensure that there is no multicollinearity in order to interpret the p-values.

# %% [markdown]
# ## Lasso Model

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# Fit the Lasso regression model
lasso = Lasso(alpha=0.001)  # Set regularization strength
lasso.fit(X_train, y_train)

# Predict on the testing set
y_pred = lasso.predict(X_test)

# Calculate mean squared error
mse = mean_squared_error(y_test, y_pred)

print(f"Lasso regression model mean squared error: {mse}")
# Out:
# Lasso regression model mean squared error: 11101829.620924594

# %%
# extract the coefficients and print them
coefficients = lasso.coef_
intercept = lasso.intercept_
feature_names = X_train.columns.tolist()
print("lasso equation: y = {} + {:.2f}*{} + {:.2f}*{} + {:.2f}*{} + {:.2f}*{}+ {:.2f}*{}+ {:.2f}*{}+ {:.2f}*{}+...".format(
    intercept, coefficients[0], feature_names[0],
    coefficients[1], feature_names[1],
    coefficients[2], feature_names[2],
    coefficients[3], feature_names[3],
    coefficients[4], feature_names[4],
    coefficients[5], feature_names[5],
    coefficients[6], feature_names[6]
))
# Out:
# lasso equation: y = 15410.350402471813 + 0.00*const + -12.49*years_of_insurance_with_us + -473.00*regular_checkup_lasy_year + 115.71*adventure_sports+ -38.10*Occupation+ -36.15*visited_doctor_last_1_year+ 40.92*cholesterol_level+...

# %% [markdown]
# ### Predicting on train and test set

# %%
y_pred_train = lasso.predict(X_train)

# %%
y_pred_test = lasso.predict(X_test)

# %%
mse = mean_squared_error(y_train, y_pred_train)
print(mse)
# Out:
# 11410209.859413883

# %%
mse = mean_squared_error(y_test, y_pred_test)
print(mse)
# Out:
# 11101829.620924594

# %%
r2_train = r2_score(y_train, y_pred_train)
print(r2_train)
# Out:
# 0.9447386070390555

# %%
r2_test = r2_score(y_test, y_pred_test)
print(r2_test)
# Out:
# 0.9450618274508376

# %%
lasso.score(X_train,y_train)
# Out:
# 0.9447386070390555

# %%
lasso.score(X_test,y_test)
# Out:
# 0.9450618274508376

# %%
mape = np.mean(np.abs((y_train - y_pred_train) / y_train))* 100
print(mape)
# Out:
# 15.250753811181372

# %%
mape = np.mean(np.abs((y_test - y_pred_test) / y_test)) * 100
print(mape)
# Out:
# 15.006362306018314

# %%
# calculate RMSE for test data
rmse_test = mean_squared_error(y_test, y_test_pred, squared=False)

# print result
print("Test RMSE:", rmse_test)
# Out:
# Test RMSE: 3331.940750461435

# %%
# calculate RMSE for test data
rmse_train = mean_squared_error(y_train, y_train_pred, squared=False)

# print result
print("Train RMSE:", rmse_train)
# Out:
# Train RMSE: 3377.9002145349114

# %% [markdown]
# ## Ridge Model

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# Fit the Ridge regression model
ridge = Ridge(alpha=0.1)  # Set regularization strength
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.1)

# %%
# Extract the coefficients and intercept
coef = ridge.coef_
intercept = ridge.intercept_

# Print the equation
equation = 'y = ' + ' + '.join(['{}x{}'.format(coef[i], i+1) for i in range(len(coef))]) + ' + {}'.format(intercept)
print(equation)
# Out:
# y = 0.0x1 + -12.491652640541847x2 + -472.9965039965449x3 + 115.71533651939559x4 + -38.098978328860426x5 + -36.15169874543777x6 + 40.92113924143083x7 + -0.027477160868464988x8 + 2.723997667228684x9 + 90.93719935619774x10 + 59.97812087318924x11 + -31.95451102197291x12 + 0.3642326465611445x13 + -1.3365847410827827x14 + -9.428212755734357x15 + -46.91846466828211x16 + 1473.2685598945486x17 + 1212.809238562498x18 + 15.430462239629529x19 + 8.583170170741871x20 + 185.65672740692003x21 + -1.215137779118032x22 + 15410.504069462651

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# Create Ridge model with alpha=1
ridge = Ridge(alpha=0.1)

# Train the model on training data
ridge.fit(X_train, y_train)

# Make predictions on test data
y_pred = ridge.predict(X_test)

# Calculate root mean squared error on test data
rmse = mean_squared_error(y_test, y_pred, squared=False)
print("Root Mean Squared Error:", rmse)

# Get the names of the variables in the equation
coef_names = list(X_train.columns)
coef_values = list(ridge.coef_)

for i in range(len(coef_names)):
    print(coef_names[i], ":", coef_values[i])
# Out:
# Root Mean Squared Error: 3331.9407472683565
# const : 0.0
# years_of_insurance_with_us : -12.491652640541847
# regular_checkup_lasy_year : -472.9965039965449
# adventure_sports : 115.71533651939559
# Occupation : -38.098978328860426
# visited_doctor_last_1_year : -36.15169874543777
# cholesterol_level : 40.92113924143083
# daily_avg_steps : -0.027477160868464988
# age : 2.723997667228684
# heart_decs_history : 90.93719935619774
# other_major_decs_history : 59.97812087318924
# Gender : -31.95451102197291
# avg_glucose_level : 0.3642326465611445
# bmi : -1.3365847410827827
# smoking_status : -9.428212755734357
# Year_last_admitted : -46.91846466828211
# weight : 1473.2685598945486
# covered_by_any_other_company : 1212.809238562498
# Alcohol : 15.430462239629529
# exercise : 8.583170170741871
# weight_change_in_last_one_year : 185.65672740692003
# fat_percentage : -1.215137779118032

# %% [markdown]
# ### Predicting on train and test sets

# %%
y_pred_train_ridge = ridge.predict(X_train)

# %%
y_pred_test_ridge = ridge.predict(X_test)

# %%
mse = mean_squared_error(y_train, y_pred_train_ridge)
print(mse)
# Out:
# 11410209.859617695

# %%
mse = mean_squared_error(y_test, y_pred_test_ridge)
print(mse)
# Out:
# 11101829.143307215

# %%
r2_train_ridge = r2_score(y_train, y_pred_train_ridge)
print(r2_train_ridge)
# Out:
# 0.9447386070380684

# %%
r2_test_ridge = r2_score(y_test, y_pred_test_ridge)
print(r2_test_ridge)
# Out:
# 0.9450618298143603

# %%
ridge.score(X_train,y_train)
# Out:
# 0.9447386070380684

# %%
ridge.score(X_test,y_test)
# Out:
# 0.9450618298143603

# %%
mape_ridge = np.mean(np.abs((y_train - y_pred_train_ridge) / y_train))* 100
print(mape_ridge)
# Out:
# 15.25074954357232

# %%
mape_ridge = np.mean(np.abs((y_test - y_pred_test_ridge) / y_test))* 100
print(mape_ridge)
# Out:
# 15.006359373149245

# %%
# calculate RMSE for test data
rmse_test = mean_squared_error(y_test, y_pred_test_ridge, squared=False)
# print result
print("Test RMSE:", rmse_test)
# Out:
# Test RMSE: 3331.9407472683565

# %%
# calculate RMSE for train data
rmse_train = mean_squared_error(y_train, y_pred_train_ridge, squared=False)
# print result
print("Train RMSE:", rmse_train)
# Out:
# Train RMSE: 3377.900214573796

# %% [markdown]
# ## Elastic Net

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error

# Define the Elastic Net model with hyperparameters alpha and l1_ratio
enet = ElasticNet(alpha=0.1, l1_ratio=0.5)

# Train the model on the training data
enet.fit(X_train, y_train)

# Predict on the test data
y_pred = enet.predict(X_test)

# Compute the mean squared error (MSE) of the predictions
mse = mean_squared_error(y_test, y_pred)

# Print the names and coefficients of the features used in the model
feature_names = X_train.columns.tolist()
coef = enet.coef_.tolist()
for feature, coef in zip(feature_names, coef):
    print(f"{feature}: {coef}")
# Out:
# const: 0.0
# years_of_insurance_with_us: -1.184504736180888
# regular_checkup_lasy_year: -455.8839341177904
# adventure_sports: 72.45414635348716
# Occupation: -33.95418023841248
# visited_doctor_last_1_year: -33.89932214376619
# cholesterol_level: 38.09751697359415
# daily_avg_steps: -0.02639756440182001
# age: 2.73417572007028
# heart_decs_history: 49.21914328471301
# other_major_decs_history: 38.861016011307115
# Gender: -27.160467949291174
# avg_glucose_level: 0.3629285674707395
# bmi: -1.046554717563888
# smoking_status: -10.505674866721444
# Year_last_admitted: -47.396640538301185
# weight: 1473.0210982163208
# covered_by_any_other_company: 966.5557847983227
# Alcohol: 13.88630259732897
# exercise: 7.886244339686662
# weight_change_in_last_one_year: 178.44900408534826
# fat_percentage: -1.110258695224447

# %%
from sklearn.linear_model import ElasticNet
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Generate synthetic data
X, y = make_regression(n_samples=1000, n_features=10, noise=0.5)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# Create and fit Elastic Net model
en = ElasticNet(alpha=0.1, l1_ratio=0.5)
en.fit(X_train, y_train)

# Make predictions on test set
y_pred = en.predict(X_test)

# Evaluate model performance
mse = mean_squared_error(y_test, y_pred)
print("Mean squared error: {:.2f}".format(mse))
# Out:
# Mean squared error: 145.16

# %%
print("Coefficients: ", en.coef_)
# Out:
# Coefficients:  [85.96195064 86.13701756 63.58563485 45.99704432 84.01361822 78.45244113
#  11.54509133 50.89085806 94.83656195 90.30473779]

# %% [markdown]
# ### Predicting on train and test data

# %%
y_pred_train_en = en.predict(X_train)

# %%
y_pred_test_en = en.predict(X_test)

# %%
mse = mean_squared_error(y_train, y_pred_train_en)
print(mse)
# Out:
# 139.77298184334572

# %%
mse = mean_squared_error(y_test, y_pred_test_en)
print(mse)
# Out:
# 145.16065477392044

# %%
r2_train_en = r2_score(y_train, y_pred_train_en)
print(r2_train_en)
# Out:
# 0.9976752434915482

# %%
r2_test_en = r2_score(y_test, y_pred_test_en)
print(r2_test_en)
# Out:
# 0.9975433128032475

# %%
mape_en = np.mean(np.abs((y_train - y_pred_train_en) / y_train))* 100
print(mape_en)
# Out:
# 6.202418055722616

# %%
mape_en_test = np.mean(np.abs((y_test - y_pred_test_en) / y_test))* 100
print(mape_en_test)
# Out:
# 6.850309459776587

# %%
en.score(X_train,y_train)
# Out:
# 0.9976752434915482

# %%
en.score(X_test,y_test)
# Out:
# 0.9975433128032475

# %%
# calculate RMSE for test data
rmse_test = mean_squared_error(y_test, y_pred_test_en, squared=False)
# print result
print("Test RMSE:", rmse_test)
# Out:
# Test RMSE: 12.048263558451916

# %%
# calculate RMSE for train data
rmse_train = mean_squared_error(y_train, y_pred_train_en, squared=False)
# print result
print("Train RMSE:", rmse_train)
# Out:
# Train RMSE: 11.82256240598229

# %% [markdown]
# # Now we will be checking the models with scaling and VIF

# %%
df_2 = pd.read_csv(r"C:\Users\cliff\OneDrive\Desktop\Great Learning\Capstone Project\Data.csv")

# %%
df_2_new = df_2.drop('applicant_id', axis= 1, inplace=True)

# %%
df_2_new = df_2.drop('Location', axis= 1)

# %%
df_2_new.head()
# Out:
#    years_of_insurance_with_us  regular_checkup_lasy_year  adventure_sports  \
# 0                           3                          1                 1
# 1                           0                          0                 0
# 2                           1                          0                 0
# 3                           7                          4                 0
# 4                           3                          1                 0
#
#   Occupation  visited_doctor_last_1_year cholesterol_level  daily_avg_steps  \
# 0    Salried                           2        125 to 150             4866
# 1    Student                           4        150 to 175             6411
# 2   Business                           4        200 to 225             4509
# 3   Business                           2        175 to 200             6214
# 4    Student                           2        150 to 175             4938
#
# ...

# %%
df_2_new["Occupation"] = df_2_new["Occupation"].replace({'Salried':2, 'Student':1, 'Business':3})

#Student=1
#Salaried=2
#Business=3

# %%
df_2_new["cholesterol_level"] = df_2_new["cholesterol_level"].replace({'125 to 150':0, '150 to 175':1, '175 to 200':2, '200 to 225' :3,
                                                                  '225 to 250':4})

#125 to 150=0
#150 to 175=1
#175 to 200=2
#200 to 225 =3
#225 to 250= 4

# %%
df_2_new["smoking_status"] = df_2_new["smoking_status"].replace({'never smoked':0, 'smokes':1, 'formerly smoked':2, 'Unknown':3})

#never smoked=0
#smokes=1
#formerly smoked =2
#Unknown= 3

# %%
df_2_new["Gender"] = df_2_new["Gender"].replace({'Male':0, 'Female':1})

#Male=0
#Female=1

# %%
df_2_new["covered_by_any_other_company"] = df_2_new["covered_by_any_other_company"].replace({'N':0, 'Y':1})

#N=0
#Y=1

# %%
df_2_new["Alcohol"] = df_2_new["Alcohol"].replace({'No':0, 'Daily':1, 'Rare': 2})

#No=0
#Daily=1
#Rare= 2

# %%
df_2_new["exercise"] = df_2_new["exercise"].replace({'No':0, 'Extreme':1, 'Moderate': 2})

#No=0
#Extreme=1
#Moderate= 2

# %%
df_2_new.head()
# Out:
#    years_of_insurance_with_us  regular_checkup_lasy_year  adventure_sports  \
# 0                           3                          1                 1
# 1                           0                          0                 0
# 2                           1                          0                 0
# 3                           7                          4                 0
# 4                           3                          1                 0
#
#    Occupation  visited_doctor_last_1_year  cholesterol_level  daily_avg_steps  \
# 0           2                           2                  0             4866
# 1           1                           4                  1             6411
# 2           3                           4                  3             4509
# 3           3                           2                  2             6214
# 4           1                           2                  1             4938
#
# ...

# %%
df_2_new.isnull().sum()
# Out:
# years_of_insurance_with_us            0
# regular_checkup_lasy_year             0
# adventure_sports                      0
# Occupation                            0
# visited_doctor_last_1_year            0
# cholesterol_level                     0
# daily_avg_steps                       0
# age                                   0
# heart_decs_history                    0
# other_major_decs_history              0
# Gender                                0
# avg_glucose_level                     0
# bmi                                 990
# smoking_status                        0
# Year_last_admitted                11881
# weight                                0
# covered_by_any_other_company          0
# Alcohol                               0
# exercise                              0
# weight_change_in_last_one_year        0
# fat_percentage                        0
# insurance_cost                        0
# dtype: int64

# %%
df_2_new.median()
# Out:
# years_of_insurance_with_us            4.0
# regular_checkup_lasy_year             0.0
# adventure_sports                      0.0
# Occupation                            2.0
# visited_doctor_last_1_year            3.0
# cholesterol_level                     1.0
# daily_avg_steps                    5089.0
# age                                  45.0
# heart_decs_history                    0.0
# other_major_decs_history              0.0
# Gender                                0.0
# avg_glucose_level                   168.0
# bmi                                  30.5
# smoking_status                        1.0
# Year_last_admitted                 2004.0
# weight                               72.0
# covered_by_any_other_company          0.0
# Alcohol                               2.0
# exercise                              2.0
# weight_change_in_last_one_year        3.0
# fat_percentage                       31.0
# insurance_cost                    27148.0
# dtype: float64

# %%
#Treating missing values using Median

medianFiller = lambda x: x.fillna(x.median())
cols_to_fill = ['bmi', 'Year_last_admitted']
df_2_new[cols_to_fill] = df_2_new[cols_to_fill].apply(medianFiller, axis=0)

# %%
df_2_new.isnull().sum()
# Out:
# years_of_insurance_with_us        0
# regular_checkup_lasy_year         0
# adventure_sports                  0
# Occupation                        0
# visited_doctor_last_1_year        0
# cholesterol_level                 0
# daily_avg_steps                   0
# age                               0
# heart_decs_history                0
# other_major_decs_history          0
# Gender                            0
# avg_glucose_level                 0
# bmi                               0
# smoking_status                    0
# Year_last_admitted                0
# weight                            0
# covered_by_any_other_company      0
# Alcohol                           0
# exercise                          0
# weight_change_in_last_one_year    0
# fat_percentage                    0
# insurance_cost                    0
# dtype: int64

# %%
from scipy.stats import zscore
df_scaled=df_2_new.apply(zscore)
df_scaled.head()
# Out:
#    years_of_insurance_with_us  regular_checkup_lasy_year  adventure_sports  \
# 0                   -0.417807                   0.188690          3.352150
# 1                   -1.568750                  -0.645043         -0.298316
# 2                   -1.185102                  -0.645043         -0.298316
# 3                    1.116783                   2.689890         -0.298316
# 4                   -0.417807                   0.188690         -0.298316
#
#    Occupation  visited_doctor_last_1_year  cholesterol_level  daily_avg_steps  \
# 0    0.006632                   -0.967205          -1.002742        -0.332228
# 1   -1.106181                    0.784661          -0.210186         1.134787
# 2    1.119445                    0.784661           1.374926        -0.671209
# 3    1.119445                   -0.967205           0.582370         0.947731
# 4   -1.106181                   -0.967205          -0.210186        -0.263863
#
# ...

# %% [markdown]
# ### Capture the target column into separate vectors for training set and test set

# %%
X2 = df_scaled.drop(["insurance_cost"], axis=1)

y2 = df_scaled.pop("insurance_cost")

# %%
y2.head()
# Out:
# 0   -0.430722
# 1   -1.464554
# 2    0.086194
# 3    0.000041
# 4    0.172347
# Name: insurance_cost, dtype: float64

# %% [markdown]
# # Splitting data into training and test set

# %%
from sklearn.model_selection import train_test_split
X2_train, X2_test, y2_train, y2_test = train_test_split(
    X2, y2, test_size=0.30, random_state=1
)

# %%
# let's add the intercept to data
import statsmodels.api as sm
X2 = sm.add_constant(X2)

# %%
print(X_2)
# Out:
#        const  years_of_insurance_with_us  regular_checkup_lasy_year  \
# 0        1.0                   -0.417807                   0.188690
# 1        1.0                   -1.568750                  -0.645043
# 2        1.0                   -1.185102                  -0.645043
# 3        1.0                    1.116783                   2.689890
# 4        1.0                   -0.417807                   0.188690
# ...      ...                         ...                        ...
# 24995    1.0                   -0.417807                  -0.645043
# 24996    1.0                    0.733135                  -0.645043
# 24997    1.0                    1.116783                  -0.645043
# 24998    1.0                   -1.185102                  -0.645043
# 24999    1.0                    1.500430                   1.022424
#
#        adventure_sports  Occupation  visited_doctor_last_1_year  \
# 0              3.352150    0.006632                   -0.967205
# ...

# %%
# For randomized data splitting
from sklearn.model_selection import train_test_split

# To build linear regression_model
import statsmodels.api as sm

# %%
# let's add the intercept to data
import statsmodels.api as sm
X2 = sm.add_constant(X2)

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(
    X2, y2, test_size=0.30, random_state=1
)

# %%
olsmod = sm.OLS(y2_train, X2_train)
olsres = olsmod.fit()

# %%
# let's print the regression summary
print(olsres.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         insurance_cost   R-squared:                       0.945
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                 1.423e+04
# Date:                Fri, 05 May 2023   Prob (F-statistic):               0.00
# Time:                        20:31:08   Log-Likelihood:                 449.79
# No. Observations:               17500   AIC:                            -855.6
# Df Residuals:                   17478   BIC:                            -684.6
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor


# Get the names of all the columns in the dataframe
column_names = X2_train.columns.tolist()

# Calculate the VIF for each column
for i in range(len(column_names)):
    vif = variance_inflation_factor(df_2_new.values, i)
    print("VIF for", column_names[i], ":", vif)
# Out:
# VIF for const : 3.7203162056522863
# VIF for years_of_insurance_with_us : 1.490637466976036
# VIF for regular_checkup_lasy_year : 1.0970448964361632
# VIF for adventure_sports : 8.13581370495046
# VIF for Occupation : 8.658225522203262
# VIF for visited_doctor_last_1_year : 2.7257880009838416
# VIF for cholesterol_level : 26.46902273843567
# VIF for daily_avg_steps : 8.784371099737237
# VIF for age : 1.0817725322509146
# VIF for heart_decs_history : 1.168532072980666
# VIF for other_major_decs_history : 1.8055419429143538
# VIF for Gender : 8.141663321800342
# VIF for avg_glucose_level : 20.276322019823667
# VIF for bmi : 2.432779304986014
# VIF for smoking_status : 725.6835155363706
# VIF for Year_last_admitted : 1072.267146268522
# VIF for weight : 1.5912108885530991
# VIF for covered_by_any_other_company : 2.805488465670437
# VIF for Alcohol : 3.9700206170123638
# VIF for exercise : 3.7871405563614498
# VIF for weight_change_in_last_one_year : 12.322517800319645
# ...

# %%
#Viewing correlation only for numerical data and not categorical data 
plt.figure(figsize=(20,20))
sns.heatmap(df_2_new.corr(), annot=True, fmt='.3f', cmap='coolwarm')
plt.show()

# %% [markdown]
# ### Let's remove/drop multicollinear columns one by one and observe the effect on our predictive mode

# %%
X2_train2 = X2_train.drop(["adventure_sports"], axis=1)
olsmod_1 = sm.OLS(y2_train, X2_train2)
olsres_1 = olsmod_1.fit()
print(
    "R-squared:",
    np.round(olsres_1.rsquared, 3),
    "\nAdjusted R-squared:",
    np.round(olsres_1.rsquared_adj, 3),
)
# Out:
# R-squared: 0.945
# Adjusted R-squared: 0.945

# %%
X2_train3 = X2_train.drop(["Occupation"], axis=1)
olsmod_2 = sm.OLS(y2_train, X2_train3)
olsres_2 = olsmod_2.fit()
print(
    "R-squared:",
    np.round(olsres_2.rsquared, 3),
    "\nAdjusted R-squared:",
    np.round(olsres_2.rsquared_adj, 3),
)
# Out:
# R-squared: 0.945
# Adjusted R-squared: 0.945

# %%
X2_train4 = X2_train.drop(["cholesterol_level"], axis=1)
olsmod_3 = sm.OLS(y2_train, X2_train4)
olsres_3 = olsmod_3.fit()
print(
    "R-squared:",
    np.round(olsres_3.rsquared, 3),
    "\nAdjusted R-squared:",
    np.round(olsres_3.rsquared_adj, 3),
)
# Out:
# R-squared: 0.945
# Adjusted R-squared: 0.945

# %%
X2_train5 = X2_train.drop(["daily_avg_steps"], axis=1)
olsmod_4 = sm.OLS(y2_train, X2_train5)
olsres_4 = olsmod_4.fit()
print(
    "R-squared:",
    np.round(olsres_4.rsquared, 3),
    "\nAdjusted R-squared:",
    np.round(olsres_4.rsquared_adj, 3),
)
# Out:
# R-squared: 0.945
# Adjusted R-squared: 0.945

# %%
X2_train6 = X2_train.drop(["Gender"], axis=1)
olsmod_5 = sm.OLS(y2_train, X2_train6)
olsres_5 = olsmod_5.fit()
print(
    "R-squared:",
    np.round(olsres_5.rsquared, 3),
    "\nAdjusted R-squared:",
    np.round(olsres_5.rsquared_adj, 3),
)
# Out:
# R-squared: 0.945
# Adjusted R-squared: 0.945

# %% [markdown]
# No Change

# %%
X2_train = X2_train.drop(["Occupation",'adventure_sports','cholesterol_level',"daily_avg_steps","age","Gender"], axis=1)

# %%
olsmod_6 = sm.OLS(y2_train, X2_train)
olsres_6 = olsmod_6.fit()
print(olsres_6.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         insurance_cost   R-squared:                       0.945
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                 1.992e+04
# Date:                Fri, 05 May 2023   Prob (F-statistic):               0.00
# Time:                        20:34:12   Log-Likelihood:                 445.30
# No. Observations:               17500   AIC:                            -858.6
# Df Residuals:                   17484   BIC:                            -734.3
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor


# Get the names of all the columns in the dataframe
column_names = X2_train.columns.tolist()

# Calculate the VIF for each column
for i in range(len(column_names)):
    vif = variance_inflation_factor(df_new.values, i)
    print("VIF for", column_names[i], ":", vif)
# Out:
# VIF for const : 3.7200706706326474
# VIF for years_of_insurance_with_us : 1.453974373104186
# VIF for regular_checkup_lasy_year : 1.0968500744153182
# VIF for visited_doctor_last_1_year : 8.135469658831871
# VIF for heart_decs_history : 8.656487092430767
# VIF for other_major_decs_history : 2.7254254194827077
# VIF for avg_glucose_level : 26.4677871087109
# VIF for bmi : 8.782110029566887
# VIF for smoking_status : 1.081539762342331
# VIF for Year_last_admitted : 1.1685017706949798
# VIF for weight : 1.8055419066251361
# VIF for covered_by_any_other_company : 8.141658142572833
# VIF for Alcohol : 20.275492333643935
# VIF for exercise : 2.4327767150698176
# VIF for weight_change_in_last_one_year : 179.58967673433935
# VIF for fat_percentage : 69.88371134923634

# %%
X2_train7 = X2_train.drop(["visited_doctor_last_1_year"], axis=1)
olsmod_6 = sm.OLS(y2_train, X2_train7)
olsres_6 = olsmod_6.fit()
print(
    "R-squared:",
    np.round(olsres_6.rsquared, 3),
    "\nAdjusted R-squared:",
    np.round(olsres_6.rsquared_adj, 3),
)
# Out:
# R-squared: 0.945
# Adjusted R-squared: 0.945

# %%
X2_train8 = X2_train.drop(["heart_decs_history"], axis=1)
olsmod_7 = sm.OLS(y2_train, X2_train8)
olsres_7 = olsmod_7.fit()
print(
    "R-squared:",
    np.round(olsres_7.rsquared, 3),
    "\nAdjusted R-squared:",
    np.round(olsres_7.rsquared_adj, 3),
)
# Out:
# R-squared: 0.945
# Adjusted R-squared: 0.945

# %%
X2_train9 = X2_train.drop(["avg_glucose_level"], axis=1)
olsmod_8 = sm.OLS(y2_train, X2_train9)
olsres_8 = olsmod_8.fit()
print(
    "R-squared:",
    np.round(olsres_8.rsquared, 3),
    "\nAdjusted R-squared:",
    np.round(olsres_8.rsquared_adj, 3),
)
# Out:
# R-squared: 0.945
# Adjusted R-squared: 0.945

# %%
X2_train10 = X2_train.drop(["bmi"], axis=1)
olsmod_9 = sm.OLS(y2_train, X2_train10)
olsres_9 = olsmod_9.fit()
print(
    "R-squared:",
    np.round(olsres_9.rsquared, 3),
    "\nAdjusted R-squared:",
    np.round(olsres_9.rsquared_adj, 3),
)
# Out:
# R-squared: 0.945
# Adjusted R-squared: 0.945

# %%
X2_train11 = X2_train.drop(["covered_by_any_other_company"], axis=1)
olsmod_10 = sm.OLS(y2_train, X2_train11)
olsres_10 = olsmod_10.fit()
print(
    "R-squared:",
    np.round(olsres_10.rsquared, 3),
    "\nAdjusted R-squared:",
    np.round(olsres_10.rsquared_adj, 3),
)
# Out:
# R-squared: 0.943
# Adjusted R-squared: 0.943

# %%
X2_train12 = X2_train.drop(["Alcohol"], axis=1)
olsmod_11 = sm.OLS(y2_train, X2_train12)
olsres_11 = olsmod_11.fit()
print(
    "R-squared:",
    np.round(olsres_11.rsquared, 3),
    "\nAdjusted R-squared:",
    np.round(olsres_11.rsquared_adj, 3),
)
# Out:
# R-squared: 0.945
# Adjusted R-squared: 0.945

# %%
X2_train13 = X2_train.drop(["weight_change_in_last_one_year"], axis=1)
olsmod_12 = sm.OLS(y2_train, X2_train13)
olsres_12 = olsmod_12.fit()
print(
    "R-squared:",
    np.round(olsres_12.rsquared, 3),
    "\nAdjusted R-squared:",
    np.round(olsres_12.rsquared_adj, 3),
)
# Out:
# R-squared: 0.944
# Adjusted R-squared: 0.944

# %%
X2_train14 = X2_train.drop(["fat_percentage"], axis=1)
olsmod_13 = sm.OLS(y2_train, X2_train14)
olsres_13 = olsmod_13.fit()
print(
    "R-squared:",
    np.round(olsres_13.rsquared, 3),
    "\nAdjusted R-squared:",
    np.round(olsres_13.rsquared_adj, 3),
)
# Out:
# R-squared: 0.945
# Adjusted R-squared: 0.945

# %%
X2_train = X2_train.drop(["visited_doctor_last_1_year",'heart_decs_history','avg_glucose_level',"bmi","Alcohol","fat_percentage"], axis=1)

# %%
olsmod_14 = sm.OLS(y2_train, X2_train)
olsres_14 = olsmod_14.fit()
print(olsres_14.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         insurance_cost   R-squared:                       0.945
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                 3.320e+04
# Date:                Fri, 05 May 2023   Prob (F-statistic):               0.00
# Time:                        20:39:14   Log-Likelihood:                 443.23
# No. Observations:               17500   AIC:                            -866.5
# Df Residuals:                   17490   BIC:                            -788.8
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor


# Get the names of all the columns in the dataframe
column_names = X2_train.columns.tolist()

# Calculate the VIF for each column
for i in range(len(column_names)):
    vif = variance_inflation_factor(df_new.values, i)
    print("VIF for", column_names[i], ":", vif)
# Out:
# VIF for const : 3.7200706706326474
# VIF for years_of_insurance_with_us : 1.453974373104186
# VIF for regular_checkup_lasy_year : 1.0968500744153182
# VIF for other_major_decs_history : 8.135469658831871
# VIF for smoking_status : 8.656487092430767
# VIF for Year_last_admitted : 2.7254254194827077
# VIF for weight : 26.4677871087109
# VIF for covered_by_any_other_company : 8.782110029566887
# VIF for exercise : 1.081539762342331
# VIF for weight_change_in_last_one_year : 1.1685017706949798

# %%
X2_train15 = X2_train.drop(["other_major_decs_history"], axis=1)
olsmod_14 = sm.OLS(y2_train, X2_train15)
olsres_14 = olsmod_14.fit()
print(
    "R-squared:",
    np.round(olsres_14.rsquared, 3),
    "\nAdjusted R-squared:",
    np.round(olsres_14.rsquared_adj, 3),
)
# Out:
# R-squared: 0.945
# Adjusted R-squared: 0.945

# %%
X2_train16 = X2_train.drop(["smoking_status"], axis=1)
olsmod_15 = sm.OLS(y2_train, X2_train16)
olsres_15 = olsmod_15.fit()
print(
    "R-squared:",
    np.round(olsres_15.rsquared, 3),
    "\nAdjusted R-squared:",
    np.round(olsres_15.rsquared_adj, 3),
)
# Out:
# R-squared: 0.945
# Adjusted R-squared: 0.945

# %%
X2_train17 = X2_train.drop(["weight"], axis=1)
olsmod_16 = sm.OLS(y2_train, X2_train17)
olsres_16 = olsmod_16.fit()
print(
    "R-squared:",
    np.round(olsres_16.rsquared, 3),
    "\nAdjusted R-squared:",
    np.round(olsres_16.rsquared_adj, 3),
)
# Out:
# R-squared: 0.442
# Adjusted R-squared: 0.442

# %%
X2_train18 = X2_train.drop(["covered_by_any_other_company"], axis=1)
olsmod_17 = sm.OLS(y2_train, X2_train18)
olsres_17 = olsmod_17.fit()
print(
    "R-squared:",
    np.round(olsres_17.rsquared, 3),
    "\nAdjusted R-squared:",
    np.round(olsres_17.rsquared_adj, 3),
)
# Out:
# R-squared: 0.943
# Adjusted R-squared: 0.943

# %%
X2_train = X2_train.drop(["other_major_decs_history",'smoking_status'], axis=1)

# %%
olsmod_18 = sm.OLS(y2_train, X2_train)
olsres_18 = olsmod_18.fit()
print(olsres_18.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         insurance_cost   R-squared:                       0.945
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                 4.268e+04
# Date:                Fri, 05 May 2023   Prob (F-statistic):               0.00
# Time:                        20:44:57   Log-Likelihood:                 442.69
# No. Observations:               17500   AIC:                            -869.4
# Df Residuals:                   17492   BIC:                            -807.2
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Assumptions of Linear Regression

# %%
df_pred = pd.DataFrame()

df_pred["Actual Values"] = y2_train.values.flatten()  # actual values
df_pred["Fitted Values"] = olsres_18.fittedvalues.values  # predicted values
df_pred["Residuals"] = olsres_18.resid.values  # residuals

df_pred.head()
# Out:
#    Actual Values  Fitted Values  Residuals
# 0       0.086194       0.164791  -0.078597
# 1      -0.258417      -0.449945   0.191528
# 2       1.378485       1.226125   0.152359
# 3       0.947721       1.276295  -0.328574
# 4       0.344652       0.639438  -0.294785

# %% [markdown]
# # TEST FOR LINEARITY AND INDEPENDENCE Why the test?

# %%
# let us plot the fitted values vs residuals
sns.set_style("whitegrid")
sns.residplot(
    data=df_pred, x="Fitted Values", y="Residuals", color="purple", lowess=True
)
plt.xlabel("Fitted Values")
plt.ylabel("Residuals")
plt.title("Fitted vs Residual plot")
plt.show()

# %%
X2_train.columns
# Out:
# Index(['const', 'years_of_insurance_with_us', 'regular_checkup_lasy_year',
#        'Year_last_admitted', 'weight', 'covered_by_any_other_company',
#        'exercise', 'weight_change_in_last_one_year'],
#       dtype='object')

# %%
# checking the distribution of variables in training set with dependent variable
sns.pairplot(X2_train[['const', 'years_of_insurance_with_us', 'regular_checkup_lasy_year',
       'Year_last_admitted', 'weight', 'covered_by_any_other_company',
       'exercise', 'weight_change_in_last_one_year']])
plt.show()

# %%
sns.histplot(df_pred["Residuals"], kde=True)
plt.title("Normality of residuals")
plt.show()

# %% [markdown]
# The residual terms are normally distributed.
#
# The QQ plot of residuals can be used to visually check the normality assumption. The normal probability plot of residuals should approximately follow a straight line.

# %%
import pylab
import scipy.stats as stats

stats.probplot(df_pred["Residuals"], dist="norm", plot=pylab)
plt.show()

# %% [markdown]
# Most of the points are lying on the straight line in QQ plot The Shapiro-Wilk test can also be used for checking the normality. The null and alternate hypotheses of the test are as follows:
#
# Null hypothesis - Data is normally distributed. Alternate hypothesis - Data is not normally distributed.

# %%
stats.shapiro(df_pred["Residuals"])
# Out:
# C:\Users\cliff\anaconda3\lib\site-packages\scipy\stats\_morestats.py:1816: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# ShapiroResult(statistic=0.9869423508644104, pvalue=7.818082241103213e-37)

# %% [markdown]
# Since p-value > 0.05, the residuals are normal as per shapiro test.

# %% [markdown]
# ### TEST FOR HOMOSCEDASTICITY

# %% [markdown]
# TEST FOR HOMOSCEDASTICITY Homoscedacity - If the variance of the residuals are symmetrically distributed across the regression line , then the data is said to homoscedastic.
#
# Heteroscedacity - If the variance is unequal for the residuals across the regression line, then the data is said to be heteroscedastic. In this case the residuals can form an arrow shape or any other non symmetrical shape.
#
# Null hypothesis : Residuals are homoscedastic Alternate hypothesis : Residuals have hetroscedasticity

# %%
import statsmodels.stats.api as sms
from statsmodels.compat import lzip

# %%
name = ["F statistic", "p-value"]
test = sms.het_goldfeldquandt(df_pred["Residuals"], X2_train)
lzip(name, test)
# Out:
# [('F statistic', 1.000980045519812), ('p-value', 0.48173772827388733)]

# %% [markdown]
# Since p-value > 0.05 we can say that the residuals are homoscedastic

# %% [markdown]
# ### All the assumptions of linear regression are now satisfied. Let's check the summary of our final model

# %%
print(olsres_18.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         insurance_cost   R-squared:                       0.945
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                 4.268e+04
# Date:                Fri, 05 May 2023   Prob (F-statistic):               0.00
# Time:                        21:21:57   Log-Likelihood:                 442.69
# No. Observations:               17500   AIC:                            -869.4
# Df Residuals:                   17492   BIC:                            -807.2
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Predictions

# %%
olsres_18.params
# Out:
# const                             0.000989
# years_of_insurance_with_us       -0.002320
# regular_checkup_lasy_year        -0.039525
# Year_last_admitted               -0.018066
# weight                            0.959166
# covered_by_any_other_company      0.038945
# exercise                          0.000422
# weight_change_in_last_one_year    0.021888
# dtype: float64

# %%
# Let us write the equation of linear regression
Equation = "insurance_cost ="
print(Equation, end=" ")
for i in range(len(X2_train.columns)):
    if i == 0:
        print(olsres_18.params[i], "+", end=" ")
    elif i != len(X2_train.columns) - 1:
        print(
            olsres_18.params[i],
            "* (",
            X2_train.columns[i],
            ")",
            "+",
            end="  ",
        )
    else:
        print(olsres_18.params[i], "* (", X2_train.columns[i], ")")
# Out:
# insurance_cost = 0.000989097789103339 + -0.0023195632110428574 * ( years_of_insurance_with_us ) +  -0.0395246003723278 * ( regular_checkup_lasy_year ) +  -0.018066030038938842 * ( Year_last_admitted ) +  0.9591661094999135 * ( weight ) +  0.03894536218911404 * ( covered_by_any_other_company ) +  0.00042240860003724514 * ( exercise ) +  0.021887596376167724 * ( weight_change_in_last_one_year )

# %% [markdown]
# ### We can now use the model for making predictions on the test data

# %%
X2_test.columns
# Out:
# Index(['const', 'years_of_insurance_with_us', 'regular_checkup_lasy_year',
#        'adventure_sports', 'Occupation', 'visited_doctor_last_1_year',
#        'cholesterol_level', 'daily_avg_steps', 'age', 'heart_decs_history',
#        'other_major_decs_history', 'Gender', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'Year_last_admitted', 'weight',
#        'covered_by_any_other_company', 'Alcohol', 'exercise',
#        'weight_change_in_last_one_year', 'fat_percentage'],
#       dtype='object')

# %%
X2_train.columns
# Out:
# Index(['const', 'years_of_insurance_with_us', 'regular_checkup_lasy_year',
#        'Year_last_admitted', 'weight', 'covered_by_any_other_company',
#        'exercise', 'weight_change_in_last_one_year'],
#       dtype='object')

# %%
# dropping columns from the test data that are not there in the training data
X2_test2 = X2_test.drop(
    ["adventure_sports",
     'visited_doctor_last_1_year',
     'daily_avg_steps', 
     'age',
       'cholesterol_level',
     'bmi',
     'heart_decs_history',
     'Occupation',
     'smoking_status',
     "heart_decs_history",
     "other_major_decs_history",
     "Gender",
     "avg_glucose_level",
    "Alcohol",
   "fat_percentage" ], axis=1
)

# %%
X2_test2.columns
# Out:
# Index(['const', 'years_of_insurance_with_us', 'regular_checkup_lasy_year',
#        'Year_last_admitted', 'weight', 'covered_by_any_other_company',
#        'exercise', 'weight_change_in_last_one_year'],
#       dtype='object')

# %%
# let's make predictions on the test set
y2_pred = olsres_18.predict(X2_test2)

# %%
# To check model performance
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# let's check the RMSE on the train data
rmse1 = np.sqrt(mean_squared_error(y2_train, df_pred["Fitted Values"]))
rmse1
# Out:
# 0.23592640155444902

# %%
# let's check the RMSE on the test data
rmse2 = np.sqrt(mean_squared_error(y2_test, y2_pred))
rmse2
# Out:
# 0.23274679361471662

# %%
# calculate MAPE and R-squared
mape = mean_absolute_percentage_error(y2_test, y2_pred)
r_squared = r2_score(y2_test, y2_pred)

print("MAPE:", mape)
print("R-squared:", r_squared)
# Out:
# MAPE: 100.83497602471098
# R-squared: 0.9450029202290997

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Initialize a Random Forest Regressor model with hyperparameters
rf_2 = RandomForestRegressor(n_estimators=100, max_depth=10, random_state=42)

# Train the model on the training set
rf_2.fit(X2_train, y2_train)

# Make predictions on the testing set
y_pred = rf_2.predict(X2_test)

# Evaluate the model performance using Root Mean Squared Error (RMSE)
mse = mean_squared_error(y2_test, y_pred)
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error (RMSE) on testing set: {rmse}")
# Out:
# Root Mean Squared Error (RMSE) on testing set: 104.68963205238012

# %%
# Make predictions on the train set
y_pred = rf_2.predict(X2_train)

# Evaluate the model performance using Root Mean Squared Error (RMSE)
mse = mean_squared_error(y2_train, y_pred)
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error (RMSE) on training set: {rmse}")
# Out:
# Root Mean Squared Error (RMSE) on training set: 39.42718136795945

# %% [markdown]
# ## Validating Random forest model on training and test sets

# %%
from sklearn.metrics import r2_score

# Evaluate the model performance using the score function of the model
score = rf_2.score(X2_test, y2_test)
print(f"Score of the model on testing set: {score:.2f}")
# Out:
# Score of the model on testing set: 0.73

# %%
from sklearn.metrics import r2_score

# Evaluate the model performance using the score function of the model
score = rf_2.score(X2_train, y2_train)
print(f"Score of the model on training set: {score:.2f}")
# Out:
# Score of the model on training set: 0.96

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import numpy as np

# assume X and y are your data and target variables respectively

# train random forest model
rf_2 = RandomForestRegressor(n_estimators=100, random_state=42)
rf_2.fit(X2_train, y2_train)

# predict on test set
y_pred = rf_2.predict(X2_test)

# calculate MAPE
mape = mean_absolute_percentage_error(y2_test, y_pred)

# calculate RMSE
rmse = np.sqrt(mean_squared_error(y2_test, y_pred))

# calculate R2 score
r2 = r2_score(y2_test, y_pred)

# print results
print("MAPE:", mape)
print("RMSE:", rmse)
print("R2 score:", r2)
# Out:
# MAPE: 1.0408658360041105
# RMSE: 102.93873271267967
# R2 score: 0.7349931295236473

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, r2_score
import numpy as np

# assume X_train and y_train are your training data and target variables respectively

# train random forest model
rf_2 = RandomForestRegressor(n_estimators=100, random_state=42)
rf_2.fit(X2_train, y2_train)

# predict on training set
y_pred_train = rf_2.predict(X2_train)

# calculate MAPE on training set
mape_train = mean_absolute_percentage_error(y2_train, y_pred_train)

# calculate RMSE on training set
rmse_train = np.sqrt(mean_squared_error(y2_train, y_pred_train))

# calculate R2 score on training set
r2_train = r2_score(y2_train, y_pred_train)

# print results
print("MAPE (training set):", mape_train)
print("RMSE (training set):", rmse_train)
print("R2 score (training set):", r2_train)
# Out:
# MAPE (training set): 0.5558102446769185
# RMSE (training set): 36.22943413356232
# R2 score (training set): 0.9703846444835412

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Split the dataset into training and testing sets
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.30, random_state=1)

# Fit the Lasso regression model
lasso = Lasso(alpha=0.001)  # Set regularization strength
lasso.fit(X2_train, y2_train)

# Predict on the testing set
y_pred = lasso.predict(X2_test)

# Calculate mean squared error
mse = mean_squared_error(y2_test, y_pred)

print(f"Lasso regression model mean squared error: {mse}")
# Out:
# Lasso regression model mean squared error: 0.2617172869808608

# %%
# extract the coefficients and print them
coefficients = lasso.coef_
intercept = lasso.intercept_
feature_names = X2_train.columns.tolist()
print("lasso equation: y = {} + {:.2f}*{} + {:.2f}*{} + {:.2f}*{} + {:.2f}*{}+ {:.2f}*{}+ {:.2f}*{}+ {:.2f}*{}+...".format(
    intercept, coefficients[0], feature_names[0],
    coefficients[1], feature_names[1],
    coefficients[2], feature_names[2],
    coefficients[3], feature_names[3],
    coefficients[4], feature_names[4],
    coefficients[5], feature_names[5],
    coefficients[6], feature_names[6]
))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[271], line 4
#       2 coefficients = lasso.coef_
#       3 intercept = lasso.intercept_
# ----> 4 feature_names = X2_train.columns.tolist()
#       5 print("lasso equation: y = {} + {:.2f}*{} + {:.2f}*{} + {:.2f}*{} + {:.2f}*{}+ {:.2f}*{}+ {:.2f}*{}+ {:.2f}*{}+...".format(
#       6     intercept, coefficients[0], feature_names[0],
#       7     coefficients[1], feature_names[1],
#    (...)
#      12     coefficients[6], feature_names[6]
#      13 ))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %% [markdown]
# ### predicting

# %%
y_pred_train = lasso.predict(X2_train)

# %%
y_pred_test = lasso.predict(X2_test)

# %%
r2_train = r2_score(y2_train, y_pred_train)
print(r2_train)
# Out:
# 0.9999944013195883

# %%
r2_test = r2_score(y2_test, y_pred_test)
print(r2_test)
# Out:
# 0.9999933109081741

# %%
lasso.score(X2_train,y2_train)
# Out:
# 0.9999944013195883

# %%
lasso.score(X2_test,y2_test)
# Out:
# 0.9999933109081741

# %%
mape = np.mean(np.abs((y2_train - y_pred_train) / y2_train))* 100
print(mape)
# Out:
# 1.273219381180345

# %%
mape_test = np.mean(np.abs((y2_test - y_pred_test) / y2_test))* 100
print(mape_test)
# Out:
# 0.8378929761221531

# %%
# calculate RMSE for test data
rmse_test = mean_squared_error(y2_test, y_test_pred, squared=False)

# print result
print("Test RMSE:", rmse_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[264], line 2
#       1 # calculate RMSE for test data
# ----> 2 rmse_test = mean_squared_error(y2_test, y_test_pred, squared=False)
#       4 # print result
#       5 print("Test RMSE:", rmse_test)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:442, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     382 def mean_squared_error(
#     383     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     384 ):
#     385     """Mean squared error regression loss.
#     386
#     387     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     440     0.825...
#     441     """
# --> 442     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     443         y_true, y_pred, multioutput
#     444     )
# ...

# %%
# calculate RMSE for test data
rmse_train = mean_squared_error(y2_train, y_train_pred, squared=False)

# print result
print("Train RMSE:", rmse_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[265], line 2
#       1 # calculate RMSE for test data
# ----> 2 rmse_train = mean_squared_error(y2_train, y_train_pred, squared=False)
#       4 # print result
#       5 print("Train RMSE:", rmse_train)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:442, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     382 def mean_squared_error(
#     383     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     384 ):
#     385     """Mean squared error regression loss.
#     386
#     387     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     440     0.825...
#     441     """
# --> 442     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     443         y_true, y_pred, multioutput
#     444     )
# ...

# %% [markdown]
# ## Ridge Model

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Split the dataset into training and testing sets
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.30, random_state=1)

# Fit the Ridge regression model
ridge = Ridge(alpha=0.1)  # Set regularization strength
ridge.fit(X2_train, y2_train)
# Out:
# Ridge(alpha=0.1)

# %%
# Extract the coefficients and intercept
coef = ridge.coef_
intercept = ridge.intercept_

# Print the equation
equation = 'y = ' + ' + '.join(['{}x{}'.format(coef[i], i+1) for i in range(len(coef))]) + ' + {}'.format(intercept)
print(equation)
# Out:
# y = 43.45971840919368x1 + 91.38450705409312x2 + 63.80231079685398x3 + 99.16772437485722x4 + 20.448650933509683x5 + 72.75346257317771x6 + 52.558719730250736x7 + 65.01410964086892x8 + 3.800409976901292x9 + 68.74928507452746x10 + -0.04534523540194613

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# Create Ridge model with alpha=1
ridge_2 = Ridge(alpha=0.1)

# Train the model on training data
ridge_2.fit(X2_train, y2_train)

# Make predictions on test data
y_pred = ridge.predict(X2_test)

# Calculate root mean squared error on test data
rmse = mean_squared_error(y2_test, y_pred, squared=False)
print("Root Mean Squared Error:", rmse)

# Get the names of the variables in the equation
coef_names = list(X2_train.columns)
coef_values = list(ridge.coef_)

for i in range(len(coef_names)):
    print(coef_names[i], ":", coef_values[i])
# Out:
# Root Mean Squared Error: 0.5110984221373482
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[268], line 18
#      15 print("Root Mean Squared Error:", rmse)
#      17 # Get the names of the variables in the equation
# ---> 18 coef_names = list(X2_train.columns)
#      19 coef_values = list(ridge.coef_)
#      21 for i in range(len(coef_names)):
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %% [markdown]
# ### predicting on train and test sets

# %%
y_pred_train_ridge = ridge_2.predict(X2_train)

# %%
y_pred_test_ridge = ridge_2.predict(X2_test)

# %%
r2_train_ridge_2 = r2_score(y2_train, y_pred_train_ridge)
print(r2_train_ridge_2)
# Out:
# 0.9999943836041559

# %%
r2_test_ridge_2 = r2_score(y2_test, y_pred_test_ridge)
print(r2_test_ridge_2)
# Out:
# 0.9999933235772457

# %%
mape_ridge_2 = np.mean(np.abs((y2_train - y_pred_train_ridge) / y2_train))* 100
print(mape_ridge_2)
# Out:
# 1.2718382942681528

# %%
mape_ridge_2_test = np.mean(np.abs((y2_test - y_pred_test_ridge) / y2_test))* 100
print(mape_ridge_2_test)
# Out:
# 0.8377360004829246

# %%
# calculate RMSE for test data
rmse_test = mean_squared_error(y2_test, y_pred_test_ridge, squared=False)
# print result
print("Test RMSE:", rmse_test)
# Out:
# Test RMSE: 0.5110984221373482

# %%
# calculate RMSE for training data
rmse_train = mean_squared_error(y2_train, y_pred_train_ridge, squared=False)
# print result
print("Test RMSE:", rmse_train)
# Out:
# Test RMSE: 0.5005834320547651

# %%
r2_test_ridge_2 = r2_score(y2_test, y_pred_test_ridge)
print(r2_test_ridge_2)
# Out:
# 0.9999933235772457

# %%
r2_train_ridge_2 = r2_score(y2_train, y_pred_train_ridge)
print(r2_train_ridge_2)
# Out:
# 0.9999943836041559

# %% [markdown]
# # Elastic Net

# %%
from sklearn.linear_model import ElasticNet
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Generate synthetic data
X2, y2 = make_regression(n_samples=1000, n_features=10, noise=0.5)

# Split data into training and testing sets
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.30)

# Create and fit Elastic Net model
en_2 = ElasticNet(alpha=0.1, l1_ratio=0.5)
en_2.fit(X2_train, y2_train)

# Make predictions on test set
y_pred = en_2.predict(X2_test)

# Evaluate model performance
mse = mean_squared_error(y2_test, y_pred)
print("Mean squared error: {:.2f}".format(mse))
# Out:
# Mean squared error: 110.69

# %%
print("Coefficients: ", en_2.coef_)
# Out:
# Coefficients:  [61.63694244 85.75802072 23.04107221 71.90391612 86.64072886 90.75322784
#  88.01876998  9.25319597 40.69823061 65.15093046]

# %% [markdown]
# ### Predicting on train and test datasets

# %%
y_pred_train_en_2 = en_2.predict(X2_train)

# %%
y_pred_test_en_2 = en_2.predict(X2_test)

# %%
r2_train_en_2 = r2_score(y2_train, y_pred_train_en_2)
print(r2_train_en_2)
# Out:
# 0.9978110464730334

# %%
r2_test_en_2 = r2_score(y2_test, y_pred_test_en_2)
print(r2_test_en_2)
# Out:
# 0.9977877222778351

# %%
mape_en_2 = np.mean(np.abs((y2_train - y_pred_train_en_2) / y2_train))* 100
print(mape_en_2)
# Out:
# 5.901017556182005

# %%
mape_en_2_test = np.mean(np.abs((y2_test - y_pred_test_en_2) / y2_test))* 100
print(mape_en_2_test)
# Out:
# 6.480561252750594

# %%
en_2.score(X2_train,y2_train)
# Out:
# 0.9978110464730334

# %%
en_2.score(X2_test,y2_test)
# Out:
# 0.9977877222778351

# %%
# calculate RMSE for test data
rmse_test = mean_squared_error(y2_test, y_pred_test_en_2, squared=False)
# print result
print("Test RMSE:", rmse_test)
# Out:
# Test RMSE: 10.520704996135287

# %%
# calculate RMSE for test data
rmse_train = mean_squared_error(y2_train, y_pred_train_en_2, squared=False)
# print result
print("Test RMSE:", rmse_train)
# Out:
# Test RMSE: 10.750995161609197

# %% [markdown]
# ## Hyper parameter tuning all the models

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.linear_model import LinearRegression, Lasso, ElasticNet, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
# define models and parameters to search
models = {
    'Linear Regression': LinearRegression(),
    'Lasso': Lasso(),
    'Elastic Net': ElasticNet(),
    'Ridge': Ridge(),
    'Random Forest': RandomForestRegressor()
}
params = {
    'Linear Regression': {},
    'Lasso': {'alpha': [0.1, 0.5, 1, 5]},
    'Elastic Net': {'alpha': [0.1, 0.5, 1, 5], 'l1_ratio': [0.1, 0.5, 0.9]},
    'Ridge': {'alpha': [0.1, 0.5, 1, 5]},
    'Random Forest': {'n_estimators': [10, 50, 100], 'max_depth': [3, 5, None]}
}

# run grid search for each model
for name, model in models.items():
    print("Running grid search for", name)
    grid = GridSearchCV(model, params[name], scoring='neg_mean_squared_error', cv=5)
    grid.fit(X2_train, y2_train)
    y2_pred = grid.predict(X2_test)
    mse = mean_squared_error(y2_test, y2_pred)
    rmse = np.sqrt(mse)
    print("Best parameters:", grid.best_params_)
    print("RMSE on test set:", rmse)
    print()
# Out:
# Running grid search for Linear Regression
# Best parameters: {}
# RMSE on test set: 0.5098293578750587
#
# Running grid search for Lasso
# Best parameters: {'alpha': 0.1}
# RMSE on test set: 0.6072889602445415
#
# Running grid search for Elastic Net
# Best parameters: {'alpha': 0.1, 'l1_ratio': 0.9}
# RMSE on test set: 2.4628031974402678
#
# Running grid search for Ridge
# Best parameters: {'alpha': 0.1}
# RMSE on test set: 0.5110775005046037
#
# Running grid search for Random Forest
# Best parameters: {'max_depth': None, 'n_estimators': 100}
# RMSE on test set: 105.6814947836617

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, ElasticNet, Ridge
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.metrics import mean_squared_error, accuracy_score

# %%
# define models to use
models = {
    'Linear Regression': LinearRegression(),
    'Lasso': Lasso(),
    'Elastic Net': ElasticNet(),
    'Ridge': Ridge(),
    'Random Forest': RandomForestRegressor()
}

# train and evaluate each model with AdaBoost
for name, model in models.items():
    print("Training and evaluating", name, "with AdaBoost")
    ada = AdaBoostRegressor(model, n_estimators=100, learning_rate=0.1, random_state=42)
    ada.fit(X2_train, y2_train)
    y2_pred = ada.predict(X2_test)
    mse = mean_squared_error(y2_test, y2_pred)
    rmse = np.sqrt(mse)
    acc = accuracy_score(np.round(y2_test), np.round(y2_pred))
    print("RMSE:", rmse)
    print("Accuracy:", acc)
    print()
# Out:
# Training and evaluating Linear Regression with AdaBoost
# RMSE: 0.5157495226560284
# Accuracy: 0.62
#
# Training and evaluating Lasso with AdaBoost
# RMSE: 1.841551550354643
# Accuracy: 0.22333333333333333
#
# Training and evaluating Elastic Net with AdaBoost
# RMSE: 49.89120067242322
# Accuracy: 0.016666666666666666
#
# Training and evaluating Ridge with AdaBoost
# RMSE: 0.547347551897734
# Accuracy: 0.59
#
# Training and evaluating Random Forest with AdaBoost
# RMSE: 91.8021001706508
# Accuracy: 0.0

# %%
Grid search cv for models before scaling
# define models to use
models = {
    'Linear Regression': LinearRegression(),
    'Lasso': Lasso(),
    'Elastic Net': ElasticNet(),
    'Ridge': Ridge(),
    'Random Forest': RandomForestRegressor()
}

# define hyperparameters to search over for each model
params = {
    'Linear Regression': {'fit_intercept': [True, False]},
    'Lasso': {'alpha': [0.1, 1, 10]},
    'Elastic Net': {'alpha': [0.1, 1, 10], 'l1_ratio': [0.25, 0.5, 0.75]},
    'Ridge': {'alpha': [0.1, 1, 10]},
    'Random Forest': {'n_estimators': [10, 50, 100], 'max_depth': [None, 5, 10]}
}

# perform grid search and evaluation for each model
for name, model in models.items():
    print("Performing grid search and evaluation for", name)
    grid = GridSearchCV(model, params[name], cv=5, n_jobs=-1)
    grid.fit(X_train, y_train)
    y_pred = grid.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)
    print("Best parameters:", grid.best_params_)
    print("RMSE:", rmse)
    print("R^2 score:", r2)
    print()
# Out:
# Performing grid search and evaluation for Linear Regression
# Best parameters: {'fit_intercept': False}
# RMSE: 0.5076792951575849
# R^2 score: 0.9999956380583914
#
# Performing grid search and evaluation for Lasso
# Best parameters: {'alpha': 0.1}
# RMSE: 0.6049551851843423
# R^2 score: 0.9999938063401451
#
# Performing grid search and evaluation for Elastic Net
# Best parameters: {'alpha': 0.1, 'l1_ratio': 0.75}
# RMSE: 6.339751858115141
# R^2 score: 0.999319786161242
#
# Performing grid search and evaluation for Ridge
# Best parameters: {'alpha': 0.1}
# RMSE: 0.5078764830583072
# R^2 score: 0.9999956346692866
#
# Performing grid search and evaluation for Random Forest
# Best parameters: {'max_depth': None, 'n_estimators': 100}
# RMSE: 127.74799631609027
# R^2 score: 0.7238092444073922
